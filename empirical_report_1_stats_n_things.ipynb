# %% [markdown]
# <a href="https://colab.research.google.com/github/jmschneider97/hello-world/blob/master/empirical_report_1_stats_n_things.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2eaad02a-f983-4fa6-9bda-de4c3988c724" name="files[]" multiple disabled />
#      <output id="result-2eaad02a-f983-4fa6-9bda-de4c3988c724">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AllOccupations_tableformat.xlsx to AllOccupations_tableformat.xlsx

# %%
import io
df = pd.read_excel(io.BytesIO(uploaded['AllOccupations_tableformat.xlsx']))
df
# Out:
#                                   Occupation Category  ... median weekly earnings between men & women
# 0   Management, professional, and related occupations  ...                                       1429
# 1   Management, professional, and related occupations  ...                                       1216
# 2   Management, professional, and related occupations  ...                                       1539
# 3   Management, professional, and related occupations  ...                                       1484
# 4   Management, professional, and related occupations  ...                                       1270
# 5   Management, professional, and related occupations  ...                                        913
# 6   Management, professional, and related occupations  ...                                       1467
# 7   Management, professional, and related occupations  ...                                       1002
# ...

# %%
df.describe()
# Out:
#        Number of Workers - Men  ...  median weekly earnings between men & women
# count                22.000000  ...                                   22.000000
# mean               2915.545455  ...                                  945.500000
# std                2197.350910  ...                                  338.144341
# min                 361.000000  ...                                  501.000000
# 25%                 828.500000  ...                                  696.000000
# 50%                2315.500000  ...                                  880.500000
# 75%                4086.500000  ...                                 1197.000000
# max                7754.000000  ...                                 1539.000000
#
# [8 rows x 6 columns]

# %%
df.groupby('Occupation Category')['Number of Workers - Men'].describe().reset_index()
# Out:
#                                  Occupation Category  count  ...      75%     max
# 0  Management, professional, and related occupations   10.0  ...  2820.75  7754.0
# 1  Natural resources, construction, and maintenan...    3.0  ...  5181.50  6223.0
# 2  Production, transportation, and material movin...    2.0  ...  6135.50  6305.0
# 3                       Sales and office occupations    2.0  ...  5197.25  5621.0
# 4                                Service occupations    5.0  ...  2258.00  2373.0
#
# [5 rows x 9 columns]

# %% [markdown]
# descriptive statistics for # of male workers, grouped by overall occupation category ^

# %%
df.groupby('Occupation Category')['Number of workers - women'].describe().reset_index()
# Out:
#                                  Occupation Category  count  ...     75%     max
# 0  Management, professional, and related occupations   10.0  ...  4806.0  5724.0
# 1  Natural resources, construction, and maintenan...    3.0  ...   187.0   191.0
# 2  Production, transportation, and material movin...    2.0  ...  1840.0  2041.0
# 3                       Sales and office occupations    2.0  ...  8397.0  9711.0
# 4                                Service occupations    5.0  ...  2184.0  2235.0
#
# [5 rows x 9 columns]

# %% [markdown]
# descriptive statistics for # of female workers, grouped by overall occupation category ^

# %%
df.groupby('Occupation Category')['Median weekly earnings - men'].describe().reset_index()
# Out:
#                                  Occupation Category  count  ...      75%     max
# 0  Management, professional, and related occupations   10.0  ...  1570.75  1910.0
# 1  Natural resources, construction, and maintenan...    3.0  ...   872.50   936.0
# 2  Production, transportation, and material movin...    2.0  ...   775.75   793.0
# 3                       Sales and office occupations    2.0  ...   896.25   949.0
# 4                                Service occupations    5.0  ...   661.00   922.0
#
# [5 rows x 9 columns]

# %% [markdown]
# descriptive statistics for median weekly earnings of men in each overall occupation category ^

# %%
df.groupby('Occupation Category')['Median weekly earnings - Women'].describe().reset_index()
# Out:
#                                  Occupation Category  count  ...      75%     max
# 0  Management, professional, and related occupations   10.0  ...  1241.25  1345.0
# 1  Natural resources, construction, and maintenan...    3.0  ...   804.00   823.0
# 2  Production, transportation, and material movin...    2.0  ...   565.75   575.0
# 3                       Sales and office occupations    2.0  ...   696.00   711.0
# 4                                Service occupations    5.0  ...   548.00   613.0
#
# [5 rows x 9 columns]

# %% [markdown]
# descriptive statistics for median weekly earnings of women in each overall occupation category ^
